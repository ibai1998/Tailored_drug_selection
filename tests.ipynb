# %% [markdown]
# ## Testing code to extract information from files

# %%
import warnings

from Bio.PDB.PDBParser import PDBParser
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/kb/mpm5p2nx6699kc04k9yj_jfh0000gn/T/ipykernel_72826/3676160219.py in <module>
#       1 import warnings
# ----> 2 from Bio import PDBConstructionWarning
#       3 #your code
#       4 with warnings.catch_warnings():
#       5     warnings.simplefilter('ignore', PDBConstructionWarning)
#
# ImportError: cannot import name 'PDBConstructionWarning' from 'Bio' (/Applications/anaconda3/lib/python3.8/site-packages/Bio/__init__.py)

# %%
import os 
import glob
CWD = os.getcwd() + '/data/'
pdb_record = glob.glob(CWD+'*pdb')[0]
print(pdb_record)
# Out:
# /Users/ibailertxundi/Desktop/tailored_drug_selection/Tailored_drug_selection/data/4jtr.pdb

# %%
from Bio.PDB.PDBParser import PDBParser
# You can use a dict to convert three letter code to one letter code
d3to1 = {'CYS': 'C', 'ASP': 'D', 'SER': 'S', 'GLN': 'Q', 'LYS': 'K',
'ILE': 'I', 'PRO': 'P', 'THR': 'T', 'PHE': 'F', 'ASN': 'N', 
'GLY': 'G', 'HIS': 'H', 'LEU': 'L', 'ARG': 'R', 'TRP': 'W', 
'ALA': 'A', 'VAL':'V', 'GLU': 'E', 'TYR': 'Y', 'MET': 'M'}

# run parser
parser = PDBParser(QUIET=True)
structure = parser.get_structure('4jtr', pdb_record)    

# iterate each model, chain, and residue
# printing out the sequence for each chain

for model in structure:
    for chain in model:
        seq = []
        residue_n = 0
        for residue in chain:
            if residue.resname in d3to1:
                seq.append(d3to1[residue.resname])
                #print('>OXIDOREDUCTASE\n',''.join(seq))
            
            else: 
                print(f'Model: {model}\nChain: {chain}\nResidue_n: {residue_n}\nResidue: {residue.resname}')
            
            residue_n += 1
# Out:
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 316
# Residue: IBP
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 317
# Residue: NAP
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 318
# Residue: EDO
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 319
# Residue: EDO
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 320
# Residue: EDO
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 321
# Residue: HOH
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 322
# Residue: HOH
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 323
# Residue: HOH
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 324
# Residue: HOH
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 325
# Residue: HOH
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 326
# Residue: HOH
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 327
# Residue: HOH
# Model: <Model id=0>
# Chain: <Chain id=A>
# Residue_n: 328
# Residue: HOH
# ...
